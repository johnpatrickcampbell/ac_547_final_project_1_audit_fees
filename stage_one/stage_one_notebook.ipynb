# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
import wrds

# %%
audit_fees = pd.read_csv("wrds_audit_fees.csv")
# Out:
# C:\Users\campb\AppData\Local\Temp\ipykernel_25280\2244071329.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   audit_fees = pd.read_csv("wrds_audit_fees.csv")
