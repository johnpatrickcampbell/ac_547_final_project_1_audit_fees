# %%
import pandas as pd
import numpy as np
import wrds
import matplotlib.pyplot as plt
import seaborn as sns

# %%
audit_fees_2025 = pd.read_csv('audit_fees_2025.csv', encoding='cp1252')
audit_fees_2024 = pd.read_csv('audit_fees_2024.csv', encoding='cp1252')
audit_fees_2023 = pd.read_csv('audit_fees_2023.csv', encoding='cp1252')
audit_fees_2022 = pd.read_csv('audit_fees_2022.csv', encoding='cp1252')
audit_fees_2021 = pd.read_csv('audit_fees_2021.csv', encoding='cp1252')
audit_fees_2020 = pd.read_csv('audit_fees_2020.csv', encoding='cp1252')

# %% [markdown]
# The user wants to concatenate the six existing DataFrames (`audit_fees_2020` through `audit_fees_2025`) into a single DataFrame.

# %%
audit_fees_2020_through_2025 = pd.concat(
    [audit_fees_2020, audit_fees_2021, audit_fees_2022, audit_fees_2023, audit_fees_2024, audit_fees_2025],
    ignore_index=True)

# %%
cam_2025 = pd.read_csv('cam_2025.csv', encoding='cp1252')
cam_2024 = pd.read_csv('cam_2024.csv', encoding='cp1252')
cam_2023 = pd.read_csv('cam_2023.csv', encoding='cp1252')
cam_2022 = pd.read_csv('cam_2022.csv', encoding='cp1252')
cam_2021 = pd.read_csv('cam_2021.csv', encoding='cp1252')
cam_2020 = pd.read_csv('cam_2020.csv', encoding='cp1252')

# %%
cam_2020_through_2025 = pd.concat(
    [cam_2020, cam_2021, cam_2022, cam_2023, cam_2024, cam_2025],
    ignore_index=True)

# %%
audit_fees_cleaned = audit_fees_2020_through_2025[["Company", "CIK Code", "SIC Code", "Audit Fees ($)", "Year Ended Date", "Market Cap ($)", "Revenue ($)", "Book Value ($)", "Assets ($)"]]
